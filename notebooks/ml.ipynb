# %% [markdown]
# # Initialize

# %%
import os, sys
sys.path.append(os.path.dirname(os.path.dirname(os.path.abspath('...'))))

from pipelines.linreg_pipe import LinearRegressionPipe


linreg = LinearRegressionPipe()
# Out:
# 25/05/25 01:03:47 WARN Utils: Your hostname, Macmanjee-2.local resolves to a loopback address: 127.0.0.1; using 192.168.1.11 instead (on interface en0)
# 25/05/25 01:03:47 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 25/05/25 01:03:47 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 25/05/25 01:03:47 WARN Utils: Service 'SparkUI' could not bind on port 4040. Attempting port 4041.
# 25/05/25 01:03:47 WARN Utils: Service 'SparkUI' could not bind on port 4041. Attempting port 4042.

# %% [markdown]
# # Preprocess and Preapare data for Linear Regression

# %%
linreg.preprocess_data()

linreg.split_data()

linreg.clean_data()

linreg.fit_feature_pipeline()
# Out:
# Fixing target column
#
# Adding day of week
#
# Transforming binary columns
#
# Splitting data into train and test
# Train rows = 700
# Test rows = 299
#
# Removing unnecessary columns
# Using columns:  ['PickUp_Colombo_ID', 'DropOff_Colombo_ID', 'N_Passengers', 'Duration_Min', 'Fare', 'DayOfWeek', 'IsMale', 'IsDay']
#
# Fitting feature pipeline
# OHE columns:  ['PickUp_Colombo_ID', 'DropOff_Colombo_ID', 'N_Passengers', 'DayOfWeek']
# Other columns:  ['IsMale', 'IsDay', 'Duration_Min']

# %% [markdown]
# # Fit Model and Check Residuals

# %%
linreg.train_model()

linreg.plot_residuals()
# Out:
# Fitting model and saving residuals
# Plotting residuals
# Mean residual: -2.90789614609821e-14
# Std residual: 3.595345103555583e-07

# %% [markdown]
# # Predict and Evaluate

# %%
linreg.get_predictions()
linreg.evaluate_predictions()
# Out:
# Getting predictions
# Evaluating predictions
# rmse: 3.550283461303748e-07
# r2: 0.9999999999999992
# mae: 2.5569001969737175e-07

# %% [markdown]
# # Feature Importance

# %%
linreg.feature_importance(k=10)
# Out:
# Pulling feature importance
